# %% [markdown]
# <a href="https://colab.research.google.com/github/AvishekPritom/Pandas-learning-path/blob/main/Pandas_10_How_to_manipulate_textual_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Titanic Data set loading......

# %%
import pandas as pd

# %%
titanic = pd.read_csv('/content/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #How to manipulate textual data

# %% [markdown]
# Make all Name characters lowercase

# %%
titanic['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# Create a new column Surname that contains the surname of the passengers by extracting the part before the comma.

# %%
titanic['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic['Surname'] = titanic['Name'].str.split(',').str.get(0)

# %%
titanic['Surname']
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Surname, Length: 891, dtype: object

# %% [markdown]
# Extract the passenger data about the countesses on board of the Titanic

# %%
titanic['Name'].str.contains('Countess')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
titanic[titanic['Name'].str.contains('Countess')]
# Out:
#      PassengerId  Survived  Pclass  \
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked Surname
# 759      0  110152  86.5   B77        S  Rothes

# %% [markdown]
# df["Age"] > 30 → True/False
#
# df[...] → filters rows using that condition ->→ selecting rows

# %% [markdown]
# Which passenger of the Titanic has the longest name?

# %%
titanic['Name'].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
titanic['Name'].str.len().idxmax()
# Out:
# 307

# %% [markdown]
# Next, we need to get the corresponding location, preferably the index label, in the table for which the name length is the largest. The idxmax() method does exactly that. It is not a string method and is applied to integers, so no str is used.

# %%
titanic.loc[titanic['Name'].str.len().idxmax(), 'Name']
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %% [markdown]
# Create a sex-short column and in the column, replace values of “male” by “M” and values of “female” by “F”.

# %%
titanic['Sex-Short'] = titanic['Sex'].replace({'male': 'M', 'female': 'F'})

# %%
titanic['Sex-Short']
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: Sex-Short, Length: 891, dtype: object

# %% [markdown]
# >Whereas replace() is not a string method, it provides a convenient way to use mappings or vocabularies to translate certain values. It requires a dictionary to define the mapping {from: to}.

# %% [markdown]
# > here is also a replace() method available to replace a specific set of characters. However, when having a mapping of multiple values, this would become:
#
# titanic["Sex_short"] = titanic["Sex"].str.replace("female", "F")
# titanic["Sex_short"] = titanic["Sex_short"].str.replace("male", "M")
# This would become cumbersome and easily lead to mistakes. Just think (or try out yourself) what would happen if those two statements are applied in the opposite order…

# %% [markdown]
# > REMEMBER
#
# String methods are available using the str accessor.
#
# String methods work element-wise and can be used for conditional indexing.
#
# The replace method is a convenient method to convert values according to a given dictionary.
